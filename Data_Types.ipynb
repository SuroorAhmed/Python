# %% [markdown]
# # Data Types

# %% [markdown]
# #### There are five main classifications of data types in Python; Numeric, Dictionary, Boolean, Set, and Sequence type

# %% [markdown]
# ### Numeric

# %%
# integers are whole numbers and decimal numbers are floats

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = 10.5

# %%
type(b)
# Out:
# float

# %%
print(a + b)
# Out:
# 20.5

# %%
type(a + b)
# Out:
# float

# %%
round(a + b)
# Out:
# 20

# %%
type(round(a + b))
# Out:
# int

# %%
# Complex numbers have real numbers with imaginary numbers. 

1 + 10j
# Out:
# (1+10j)

# %%
type(1 + 10j)
# Out:
# complex

# %% [markdown]
# ### Boolean

# %% [markdown]
# #### The Boolean data type is a simple data type with two values: True and False.

# %%
1 > 5
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1 < 5
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(1 > 5)
# Out:
# bool

# %% [markdown]
# ### String

# %% [markdown]
# #### In Python, the string (str) data type is used to represent text. A string is a sequence of characters enclosed in either single quotes ('), double quotes ("), or triple quotes (''' or """).

# %%
'Can have single quote marks'
# Out:
# 'Can have single quote marks'

# %%
"Can have double quote marks"
# Out:
# 'Can have double quote marks'

# %%
# Triple quote marks can be used to create multiline text 

multiline = """
This is line 1 
This is line 2 

"""

# %%
multiline
# Out:
# '\nThis is line 1 \nThis is line 2 \n\n'

# %%
# Python uses \n to interpret new lines

# %%
x = "Apples \nOranges"

# %%
print(x)
# Out:
# Apples
# Oranges

# %%
y = "This is line 1 \nThis is line 2"

# %%
print(y)
# Out:
# This is line 1
# This is line 2

# %%
# \t can be used to create tabs, tabs are space between text.

x = "Apples\tOranges"

# %%
print(x)
# Out:
# Apples	Oranges

# %%
# Special sequence - use a \ to recognize apostrophes in a string, or use mixed quotation types. 

x = 'My cat\'s cute!'

# %%
print(x)
# Out:
# My cat's cute!

# %%
x = "My cat's cute!"

# %%
print(x)
# Out:
# My cat's cute!

# %%
# Raw strings - adding r in front of the string allows it to be displayed in it's original form. 

x = r'My cat\'s cute!'

# %%
print(x)
# Out:
# My cat\'s cute!

# %%
# Operators on Strings

"Hello!" *3
# Out:
# 'Hello!Hello!Hello!'

# %%
"Hello" + "World!"
# Out:
# 'HelloWorld!'

# %% [markdown]
# ### Lists

# %% [markdown]
# #### A list in Python is an ordered collection of items that can be of any type. Lists are defined by enclosing a comma-separated sequence of items in square brackets [].

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
type([1,2,3])
# Out:
# list

# %%
cat_list = ['Ragdoll', 10, 'Shorthair', 3, True]

# %%
print(cat_list)
# Out:
# ['Ragdoll', 10, 'Shorthair', 3, True]

# %%
cat_list1 = ['Tabby', 'Ragdoll', 'Shorthair']
cat_list2 = ['Persian','Maine Coon', 'Siamese']

# %%
cat_list3 = cat_list1 + cat_list2

# %%
print(cat_list3)
# Out:
# ['Tabby', 'Ragdoll', 'Shorthair', 'Persian', 'Maine Coon', 'Siamese']

# %%
cat_list3.append('Bengal')

# %%
print(cat_list3)
# Out:
# ['Tabby', 'Ragdoll', 'Shorthair', 'Persian', 'Maine Coon', 'Siamese', 'Bengal']

# %%
cat_list3[1]
# Out:
# 'Ragdoll'

# %%
cat_list3[0:4]
# Out:
# ['Tabby', 'Ragdoll', 'Shorthair', 'Persian']

# %%
cat_list3[1] = 'Sphynx'

# %%
print(cat_list3)
# Out:
# ['Tabby', 'Sphynx', 'Shorthair', 'Persian', 'Maine Coon', 'Siamese', 'Bengal']

# %%
cat_list3[2]
# Out:
# 'Shorthair'

# %%
cat_list3[2][0]
# Out:
# 'S'

# %% [markdown]
# ### Tuples

# %% [markdown]
# #### A tuple in Python is similar to a list in that it is an ordered collection of items. However, tuples are defined by enclosing a comma-separated sequence of items in parentheses ().

# %% [markdown]
# Tuples are immutable, which means you cannot add, remove, or change items after the tuple is created. This can be useful in situations where you want to ensure that the collection of items remains constant throughout the program.

# %% [markdown]
# Although you can't modify a tuple, you can concatenate tuples to form a new tuple, or multiply a tuple by an integer to form a new tuple that repeats the original tuple's items.

# %%
(1,2,3)
# Out:
# (1, 2, 3)

# %%
type((1,2,3))
# Out:
# tuple

# %%
random_tuple = (1,2,3,4,5)

print(random_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Tuples are immutable

random_tuple.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 random_tuple.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ### Sets

# %% [markdown]
# #### A set in Python is an unordered collection of unique items. Sets are defined by enclosing a comma-separated sequence of items in curly braces {}.

# %% [markdown]
# Sets are unordered, which means that the order in which items are added to a set is not necessarily the same order in which they are iterated.
#
# Unlike lists and tuples, sets cannot contain duplicate items. If you try to add a duplicate item to a set, it will be ignored.
#
# Sets are mutable, which means you can add and remove items from a set. However, because sets are unordered, they do not support indexing or slicing.
#
# Python provides a variety of operations to perform on sets, such as union (|), intersection (&), difference (-), and symmetric difference (^).

# %%
first_set = {1,2,3}
print(first_set)
# Out:
# {1, 2, 3}

# %%
second_set = {1,2,3,'A','B','C'}
print(second_set)
# Out:
# {1, 2, 3, 'A', 'C', 'B'}

# %%
third_set ={1,1,2,3,4,5,5,6,5,6,7,7,8}
print(third_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# #### A dictionary is an unordered collection of items. Each item stored in a dictionary has a key - value pair. You can use the key to access the corresponding value. Dictionaries are defined by enclosing a comma-separated sequence of key-value pairs in curly braces {}. The key and value are separated by a colon :.

# %%
client_pets = {'Client Name':'Amy Finch', 'Pet Name': 'Andy', 'Pet Age': 5}

print(client_pets)
# Out:
# {'Client Name': 'Amy Finch', 'Pet Name': 'Andy', 'Pet Age': 5}

# %%
type(client_pets)
# Out:
# dict

# %%
client_pets.keys()
# Out:
# dict_keys(['Client Name', 'Pet Name', 'Pet Age'])

# %%
client_pets.values()
# Out:
# dict_values(['Amy Finch', 'Andy', 5])

# %%
ice_cream_shop = {'Employees': 10, 'Flavors':['Chocolate', 'Vanilla', 'Strawberry'], 'Store hours': '12pm - 8pm'}
print(ice_cream_shop)
# Out:
# {'Employees': 10, 'Flavors': ['Chocolate', 'Vanilla', 'Strawberry'], 'Store hours': '12pm - 8pm'}

# %%
ice_cream_shop.keys()
# Out:
# dict_keys(['Employees', 'Flavors', 'Store hours'])

# %%
ice_cream_shop['Flavors']
# Out:
# ['Chocolate', 'Vanilla', 'Strawberry']

# %%
ice_cream_shop['Store hours']
# Out:
# '12pm - 8pm'

# %%
# Nested Dictionaries

nested_dict = {1:'Apples', 2:'Oranges', 3:'Pears', 4:{1:'Pineapple', 2:'Mango', 3:'Passion Fruit'}}

# %%
print(nested_dict)
# Out:
# {1: 'Apples', 2: 'Oranges', 3: 'Pears', 4: {1: 'Pineapple', 2: 'Mango', 3: 'Passion Fruit'}}

# %%
nested_dict[3]
# Out:
# 'Pears'

# %%
nested_dict[4]
# Out:
# {1: 'Pineapple', 2: 'Mango', 3: 'Passion Fruit'}

# %%
nested_dict[4][2]
# Out:
# 'Mango'

# %% [markdown]
# ### Converting Data Types

# %%
# Implicit conversion is done automatically

num_int = 10

num_float = 2.1

num_imp_con = num_int/num_float

print(num_imp_con)
# Out:
# 4.761904761904762

# %%
type(num_imp_con)
# Out:
# float

# %%
# Explicit conversion - this is done manually

num_int1 = 7

num_str2 = '7'

num_int_conv = int(num_str2)

num_sum = num_int1+num_int_conv

print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
# Converting an list to a set

my_list = [1,1,2,3,4,4,5,6,6]

my_list_conv = set(my_list)

print(my_list_conv)
# Out:
# {1, 2, 3, 4, 5, 6}
