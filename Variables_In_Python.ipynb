# %% [markdown]
# Variables in Python

# %%
x=25
print(x)
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y='Raspberry White Chocolate'
print(y)
# Out:
# Raspberry White Chocolate

# %%
type(y)
# Out:
# str

# %%
y='Raspbarry' 

y='Vanilla'

print(y)
# Out:
# Vanilla

# %%
y='Raspberry White Chocolate'

Y='Vanilla'

print(y)
# Out:
# Raspberry White Chocolate

# %%
print(Y)
# Out:
# Vanilla

# %%
x,y,z = 'Chocolate', 'Raspberry White Chocolate', 'Vanilla'

print(x,y,z)
# Out:
# Chocolate Raspberry White Chocolate Vanilla

# %%
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Raspberry White Chocolate
# Vanilla

# %%
x = y = z = 'Orange Cream'

print(x)
print(y)
print(z)
# Out:
# Orange Cream
# Orange Cream
# Orange Cream

# %% [markdown]
# Creating A List

# %%
ice_cream = ['Chocolate', 'Raspberry White Chocolate', 'Vanilla']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Raspberry White Chocolate
# Vanilla
