# %%
import pandas as pd

df = pd.read_csv("health_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("health_data.csv")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/suroora'

# %%
os.listdir()
# Out:
# ['Funnel.R',
#  '.Rhistory',
#  '.config',
#  'Music',
#  '.condarc',
#  'py',
#  'Untitled1.ipynb',
#  '.DS_Store',
#  'Joins.R',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  'Python',
#  'anaconda_projects',
#  'Untitled.ipynb',
#  'mtcars1.ipynb',
#  '.zshrc',
#  'HelloWorldPY.ipynb',
#  '.local',
#  'Pictures',
#  'R',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'PythonPractice1.ipynb 2',
#  'PythonPractice2.ipynb',
#  'PythonPractice1.ipynb.zip',
#  'Public',
#  '.tcshrc',
#  '.RData',
#  '.virtual_documents',
#  '.anaconda',
#  'Movies',
#  '.Rapp.history',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  '.pydataset',
#  'Documents',
#  'PythonPractice1.ipynb',
#  '.mysql_history',
#  '.bash_profile',
#  'Downloads',
#  '.continuum',
#  '.gitconfig',
#  '.zsh_sessions',
#  '.conda']

# %%
import pandas as pd
import os

# Print current working directory to see where Python is looking
print("Current working directory:", os.getcwd())

# Option 1: Provide the full path to the file
# df = pd.read_csv("/full/path/to/health_data.csv")

# Option 2: Change the working directory to where the file is located
# os.chdir("/path/to/directory/containing/file")
# df = pd.read_csv("health_data.csv")

# Option 3: Make sure the file exists and the name is correct
# Common issues: typos in filename, wrong file extension, or file in different directory
# Out:
# Current working directory: /Users/suroora

# %%
import pandas as pd
df = pd.read_csv("health_data.csv")
df.head()
# Out:
#    patient_id  age gender  blood_pressure  cholesterol     diagnosis
# 0           1   25      F           120.0        200.0      Diabetes
# 1           2   34      M           140.0        230.0  Hypertension
# 2           3   45      F           135.0          NaN      Diabetes
# 3           4   52      F             NaN        180.0           NaN
# 4           5   28      M           118.0        190.0           NaN

# %%
#View the first few rows
df.head()
# Out:
#    patient_id  age gender  blood_pressure  cholesterol     diagnosis
# 0           1   25      F           120.0        200.0      Diabetes
# 1           2   34      M           140.0        230.0  Hypertension
# 2           3   45      F           135.0          NaN      Diabetes
# 3           4   52      F             NaN        180.0           NaN
# 4           5   28      M           118.0        190.0           NaN

# %%
#Check data structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      20 non-null     int64
#  1   age             20 non-null     int64
#  2   gender          20 non-null     object
#  3   blood_pressure  17 non-null     float64
#  4   cholesterol     16 non-null     float64
#  5   diagnosis       13 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.1+ KB

# %%
#Summary statistics
df.describe()
# Out:
#        patient_id       age  blood_pressure  cholesterol
# count    20.00000  20.00000       17.000000    16.000000
# mean     10.50000  45.45000      142.235294   218.187500
# std       5.91608  13.78968       16.021585    28.378909
# min       1.00000  25.00000      118.000000   180.000000
# 25%       5.75000  33.75000      132.000000   197.250000
# 50%      10.50000  44.50000      140.000000   212.500000
# 75%      15.25000  55.50000      155.000000   232.500000
# max      20.00000  72.00000      170.000000   275.000000
